# %% [markdown]
# # Yelp API Core
# Jacob Tanzi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# !pip install tqdm
# !pip install yelpapi
# Out:
# Requirement already satisfied: tqdm in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)
# Collecting yelpapi
#   Downloading yelpapi-2.5.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jacob\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Installing collected packages: yelpapi
# Successfully installed yelpapi-2.5.0

# %% [markdown]
# ### Credentials and Accessing  API

# %%
with open('/Users/Jacob/.secret/yelp_api.json') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client id', 'api key'])

# %%
yelp = YelpAPI(login['api key'], timeout_s=5.0)

# %%
LOCATION = 'Seattle, WA 98104'
TERM = 'bbq'

# %%
LOCATION.split(',')[0]
# Out:
# 'Seattle'

# %%
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)

JSON_FILE = FOLDER+f"{LOCATION.split(',')[0]}-{TERM}.json"

# %%
JSON_FILE
# Out:
# 'Data/Seattle-bbq.json'

# %% [markdown]
# ## File and Results

# %%
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f'[i] {JSON_FILE} not found. Saving empty list to file.')
    
    
    # save an empty list
    with open(JSON_FILE,'w') as f:
        json.dump([],f)  
# If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Seattle-bbq.json already exists.

# %%
results = yelp.search_query(term= TERM, location = LOCATION)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 531

# %%
results['region']
# Out:
# {'center': {'longitude': -122.32967376708984, 'latitude': 47.60222492142979}}

# %%
results['businesses']
# Out:
# [{'id': 'E0jzAxh2u7ifsOeZ4qnp6A',
#   'alias': 'wood-shop-bbq-seattle',
#   'name': 'Wood Shop BBQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ta1019UIIFLK3YdGKhgCjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wood-shop-bbq-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 688,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.59906, 'longitude': -122.29914},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2513 S Jackson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98144',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2513 S Jackson St', 'Seattle, WA 98144']},
#   'phone': '+12064857381',
#   'display_phone': '(206) 485-7381',
#   'distance': 2310.9832836596693},
#  {'id': 'oom3dxWO6NVPmbXYanCfqQ',
#   'alias': 'bellwether-bbq-and-grill-seattle',
#   'name': 'Bellwether BBQ&Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pBwgaV1aOPPcAxK6_DneDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bellwether-bbq-and-grill-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 26,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.59734508353989,
#    'longitude': -122.32602948410072},
#   'transactions': [],
#   'location': {'address1': '609 S Weller St',
#    'address2': 'Ste C',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['609 S Weller St', 'Ste C', 'Seattle, WA 98104']},
#   'phone': '+12062238528',
#   'display_phone': '(206) 223-8528',
#   'distance': 607.5290684720885},
#  {'id': 'fy8zyFKcG45cfh3PvYvx-Q',
#   'alias': 'hole-in-the-wall-bbq-seattle',
#   'name': 'Hole In the Wall BBQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8UipIn-G6r_l7Ha9qMGrVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hole-in-the-wall-bbq-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 271,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.60248, 'longitude': -122.33167},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '215 James St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['215 James St', 'Seattle, WA 98104']},
#   'phone': '+12066228717',
#   'display_phone': '(206) 622-8717',
#   'distance': 158.06381516654352},
#  {'id': 'HZTlGFXupOqtPCyYkdeDIw',
#   'alias': 'pikes-pit-bar-b-que-seattle',
#   'name': "Pike's Pit Bar-B-Que",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wHUjh9eU88RpdQqlUHgT5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pikes-pit-bar-b-que-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 251,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.608664, 'longitude': -122.340955},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1505 Pike Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['1505 Pike Pl', 'Seattle, WA 98101']},
#   'phone': '+12065380779',
#   'display_phone': '(206) 538-0779',
#   'distance': 1108.1362146109316},
#  {'id': 'e8UiD4SOyfyv5PIB5i1EvQ',
#   'alias': 'kau-kau-barbeque-seattle',
#   'name': 'Kau Kau Barbeque',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq0CJNCDSHQnqn7XuRmK1g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kau-kau-barbeque-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 1202,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59847, 'longitude': -122.32471},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '656 S King St',
#    'address2': None,
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['656 S King St', 'Seattle, WA 98104']},
#   'phone': '+12066824006',
#   'display_phone': '(206) 682-4006',
#   'distance': 564.151185588291},
#  {'id': '6_zxj1HKD8mSNI8Rh2cxog',
#   'alias': 'jacks-bbq-sodo-seattle-2',
#   'name': "Jack's BBQ - SoDo",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2fyLLhRe0zNKrUnapd114w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacks-bbq-sodo-seattle-2?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 970,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.568253286253, 'longitude': -122.322438037435},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3924 Airport Way S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98108',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['3924 Airport Way S', 'Seattle, WA 98108']},
#   'phone': '+12064674038',
#   'display_phone': '(206) 467-4038',
#   'distance': 3816.2515730698824},
#  {'id': 'VJ9gsqxrMPb2rt58wyDswQ',
#   'alias': 'pecos-pit-bar-b-que-seattle-3',
#   'name': 'Pecos Pit Bar-B-Que',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NaveRX5GkZOo6-9215zSqg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pecos-pit-bar-b-que-seattle-3?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 472,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.58215, 'longitude': -122.3338},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2260 1st Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98134',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['2260 1st Ave S', 'Seattle, WA 98134']},
#   'phone': '+12066230629',
#   'display_phone': '(206) 623-0629',
#   'distance': 2254.663043218505},
#  {'id': 'jJGEKgCtJpFbFGlwl8d54w',
#   'alias': 'c-davis-texas-bbq-seattle',
#   'name': 'C. Davis Texas BBQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qvfcbqneVNtj-weCVuweAg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/c-davis-texas-bbq-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 25,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.594464, 'longitude': -122.31013},
#   'transactions': [],
#   'location': {'address1': '898 Rainier Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98144',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['898 Rainier Ave S', 'Seattle, WA 98144']},
#   'phone': '+12062355111',
#   'display_phone': '(206) 235-5111',
#   'distance': 1700.9859134247924},
#  {'id': 'YiqbI1zr5dd8qTVw6GMzAA',
#   'alias': 'ton-kiang-barbeque-noodle-house-seattle',
#   'name': 'Ton Kiang Barbeque Noodle House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DMbzoRHRXPsCGmDlG_bqeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ton-kiang-barbeque-noodle-house-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 165,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'cantonese', 'title': 'Cantonese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.59763, 'longitude': -122.32415},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '668 S Weller St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['668 S Weller St', 'Seattle, WA 98104']},
#   'phone': '+12066223388',
#   'display_phone': '(206) 622-3388',
#   'distance': 652.8599569313595},
#  {'id': 'nUkPOJ5p4E9U7e2DbOzzMw',
#   'alias': 'meet-korean-bbq-seattle',
#   'name': 'Meet Korean BBQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UwvDMA7r9nHdzDLAqMfbow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/meet-korean-bbq-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 321,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.614331, 'longitude': -122.325201},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '500 E Pike St',
#    'address2': None,
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98122',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['500 E Pike St', 'Seattle, WA 98122']},
#   'phone': '+12066952621',
#   'display_phone': '(206) 695-2621',
#   'distance': 1387.1771911760188},
#  {'id': '_9AhpkxGdGSeGAbqVaNiaA',
#   'alias': 'jacks-bbq-columbia-tower-seattle-6',
#   'name': "Jack's BBQ - Columbia Tower",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TOscnJTHNFLxp97YOOe8BQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacks-bbq-columbia-tower-seattle-6?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 32,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60453, 'longitude': -122.33061},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '701 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['701 5th Ave', 'Seattle, WA 98104']},
#   'phone': '+12064674038',
#   'display_phone': '(206) 467-4038',
#   'distance': 265.7504762652201},
#  {'id': 'XeT3JaiYfd2bSYZPVyrI9A',
#   'alias': 'kings-barbeque-house-seattle-2',
#   'name': "King's Barbeque House",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l_iiZAZTVAu19K95DhZu_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kings-barbeque-house-seattle-2?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 82,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 47.59779, 'longitude': -122.32601},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '518 6th Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['518 6th Ave S', 'Seattle, WA 98104']},
#   'phone': '+12066222828',
#   'display_phone': '(206) 622-2828',
#   'distance': 560.1771958572238},
#  {'id': '-YB_t6sQOO9Ivfuy85_YpQ',
#   'alias': 'smokestack-lightning-bbq-seattle',
#   'name': 'Smokestack Lightning BBQ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MbLuTYnAvIDm6x9DRpERMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smokestack-lightning-bbq-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 12,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 47.6112518310547,
#    'longitude': -122.334930419922},
#   'transactions': [],
#   'location': {'address1': '',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['Seattle, WA 98101']},
#   'phone': '+12069600460',
#   'display_phone': '(206) 960-0460',
#   'distance': 860.5000704826358},
#  {'id': 'XRq4pEDqhwdU0byGwszCFA',
#   'alias': 'baegopa-seattle',
#   'name': 'Baegopa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YGpvIODWLuRA6IUUmQtI2A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baegopa-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 202,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59805457325023,
#    'longitude': -122.32417434666895},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '509 7th Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['509 7th Ave S', 'Seattle, WA 98104']},
#   'phone': '+12064857137',
#   'display_phone': '(206) 485-7137',
#   'distance': 620.5328993062496},
#  {'id': 'Y8t4us06vG1OG7TcqNTrZg',
#   'alias': 'jacks-bbq-south-lake-union-seattle-2',
#   'name': "Jack's BBQ - South Lake Union",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gX2EJet7pd30m_GP9wpOgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacks-bbq-south-lake-union-seattle-2?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 202,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.620538, 'longitude': -122.339396},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '228 9th Ave N',
#    'address2': None,
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98109',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['228 9th Ave N', 'Seattle, WA 98109']},
#   'phone': '+12067087642',
#   'display_phone': '(206) 708-7642',
#   'distance': 2162.810885241355},
#  {'id': 'OjX2LacSZd_w2Olmx55HJA',
#   'alias': 'harbor-city-restaurant-seattle',
#   'name': 'Harbor City Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I0ps32fRuvED6UMIJiRU3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/harbor-city-restaurant-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 2034,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.59821, 'longitude': -122.32339},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '707 S King St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['707 S King St', 'Seattle, WA 98104']},
#   'phone': '+12066212228',
#   'display_phone': '(206) 621-2228',
#   'distance': 648.0086873857492},
#  {'id': '663yP3mdqau3iMUVblMaAw',
#   'alias': 'ishoni-yakiniku-seattle',
#   'name': 'Ishoni Yakiniku',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rTINNfRHlyKRS-LC9M1aow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ishoni-yakiniku-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 233,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.624618, 'longitude': -122.321194},
#   'transactions': ['delivery', 'restaurant_reservation'],
#   'location': {'address1': '611 Broadway E',
#    'address2': None,
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98102',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['611 Broadway E', 'Seattle, WA 98102']},
#   'phone': '+14254550898',
#   'display_phone': '(425) 455-0898',
#   'distance': 2569.0975384712833},
#  {'id': 'ps9ZlLoLYTfK87IjW9REfg',
#   'alias': 'radiator-whiskey-seattle',
#   'name': 'Radiator Whiskey',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2Z38xi6tz7ErO2eXl22d8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/radiator-whiskey-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 1395,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 47.608949, 'longitude': -122.340599},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '94 Pike St',
#    'address2': 'Ste 30',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['94 Pike St', 'Ste 30', 'Seattle, WA 98101']},
#   'phone': '+12064674268',
#   'display_phone': '(206) 467-4268',
#   'distance': 1109.0142554851489},
#  {'id': 'du2ezG1o0QBcRQr4CbA1AA',
#   'alias': 'asia-bar-b-que-seattle',
#   'name': 'Asia Bar-B-Que',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MdEEiQ7t9EgcjZM-2mhHEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asia-bar-b-que-seattle?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 57,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 47.59901, 'longitude': -122.32469},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '655 S Jackson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Seattle',
#    'zip_code': '98104',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['655 S Jackson St', 'Seattle, WA 98104']},
#   'phone': '+12066242275',
#   'display_phone': '(206) 624-2275',
#   'distance': 523.2337928126111},
#  {'id': '8Puu4LRQRMyQN4xeAkN-Ug',
#   'alias': 'the-hart-and-the-hunter-seattle-2',
#   'name': 'The Hart and The Hunter',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hoiHJVrZvZzHdkzXG8fTnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-hart-and-the-hunter-seattle-2?adjust_creative=BoLa0Tsmk6Ez30bPKtKPjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BoLa0Tsmk6Ez30bPKtKPjg',
#   'review_count': 243,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 47.60989, 'longitude': -122.34038},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '111 Pine St',
#    'address2': '',
#    'address3': None,
#    'city': 'Seattle',
#    'zip_code': '98101',
#    'country': 'US',
#    'state': 'WA',
#    'display_address': ['111 Pine St', 'Seattle, WA 98101']},
#   'phone': '+12065960700',
#   'display_phone': '(206) 596-0700',
#   'distance': 1163.7634799711577}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                    alias  \
# 0   E0jzAxh2u7ifsOeZ4qnp6A                    wood-shop-bbq-seattle
# 1   oom3dxWO6NVPmbXYanCfqQ         bellwether-bbq-and-grill-seattle
# 2   fy8zyFKcG45cfh3PvYvx-Q             hole-in-the-wall-bbq-seattle
# 3   HZTlGFXupOqtPCyYkdeDIw              pikes-pit-bar-b-que-seattle
# 4   e8UiD4SOyfyv5PIB5i1EvQ                 kau-kau-barbeque-seattle
# 5   6_zxj1HKD8mSNI8Rh2cxog                 jacks-bbq-sodo-seattle-2
# 6   VJ9gsqxrMPb2rt58wyDswQ            pecos-pit-bar-b-que-seattle-3
# 7   jJGEKgCtJpFbFGlwl8d54w                c-davis-texas-bbq-seattle
# 8   YiqbI1zr5dd8qTVw6GMzAA  ton-kiang-barbeque-noodle-house-seattle
# 9   nUkPOJ5p4E9U7e2DbOzzMw                  meet-korean-bbq-seattle
# 10  _9AhpkxGdGSeGAbqVaNiaA       jacks-bbq-columbia-tower-seattle-6
# 11  XeT3JaiYfd2bSYZPVyrI9A           kings-barbeque-house-seattle-2
# 12  -YB_t6sQOO9Ivfuy85_YpQ         smokestack-lightning-bbq-seattle
# 13  XRq4pEDqhwdU0byGwszCFA                          baegopa-seattle
# 14  Y8t4us06vG1OG7TcqNTrZg     jacks-bbq-south-lake-union-seattle-2
# 15  OjX2LacSZd_w2Olmx55HJA           harbor-city-restaurant-seattle
# 16  663yP3mdqau3iMUVblMaAw                  ishoni-yakiniku-seattle
# 17  ps9ZlLoLYTfK87IjW9REfg                 radiator-whiskey-seattle
# 18  du2ezG1o0QBcRQr4CbA1AA                   asia-bar-b-que-seattle
# 19  8Puu4LRQRMyQN4xeAkN-Ug        the-hart-and-the-hunter-seattle-2
#
#                                name  \
# 0                     Wood Shop BBQ
# 1              Bellwether BBQ&Grill
# 2              Hole In the Wall BBQ
# 3              Pike's Pit Bar-B-Que
# 4                  Kau Kau Barbeque
# 5                 Jack's BBQ - SoDo
# 6               Pecos Pit Bar-B-Que
# 7                C. Davis Texas BBQ
# 8   Ton Kiang Barbeque Noodle House
# 9                   Meet Korean BBQ
# 10      Jack's BBQ - Columbia Tower
# 11            King's Barbeque House
# 12         Smokestack Lightning BBQ
# 13                          Baegopa
# 14    Jack's BBQ - South Lake Union
# 15           Harbor City Restaurant
# 16                  Ishoni Yakiniku
# 17                 Radiator Whiskey
# 18                   Asia Bar-B-Que
# 19          The Hart and The Hunter
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/ta1019...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/pBwgaV...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/8UipIn...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/wHUjh9...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/rq0CJN...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/2fyLLh...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/NaveRX...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/qvfcbq...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/DMbzoR...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/UwvDMA...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/TOscnJ...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/l_iiZA...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/MbLuTY...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/YGpvIO...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/gX2EJe...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/I0ps32...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/rTINNf...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/2Z38xi...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/MdEEiQ...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/hoiHJV...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/wood-shop-bbq-seattle...           688
# 1   https://www.yelp.com/biz/bellwether-bbq-and-gr...            26
# 2   https://www.yelp.com/biz/hole-in-the-wall-bbq-...           271
# 3   https://www.yelp.com/biz/pikes-pit-bar-b-que-s...           251
# 4   https://www.yelp.com/biz/kau-kau-barbeque-seat...          1202
# 5   https://www.yelp.com/biz/jacks-bbq-sodo-seattl...           970
# 6   https://www.yelp.com/biz/pecos-pit-bar-b-que-s...           472
# 7   https://www.yelp.com/biz/c-davis-texas-bbq-sea...            25
# 8   https://www.yelp.com/biz/ton-kiang-barbeque-no...           165
# 9   https://www.yelp.com/biz/meet-korean-bbq-seatt...           321
# 10  https://www.yelp.com/biz/jacks-bbq-columbia-to...            32
# 11  https://www.yelp.com/biz/kings-barbeque-house-...            82
# 12  https://www.yelp.com/biz/smokestack-lightning-...            12
# 13  https://www.yelp.com/biz/baegopa-seattle?adjus...           202
# 14  https://www.yelp.com/biz/jacks-bbq-south-lake-...           202
# 15  https://www.yelp.com/biz/harbor-city-restauran...          2034
# 16  https://www.yelp.com/biz/ishoni-yakiniku-seatt...           233
# 17  https://www.yelp.com/biz/radiator-whiskey-seat...          1395
# 18  https://www.yelp.com/biz/asia-bar-b-que-seattl...            57
# 19  https://www.yelp.com/biz/the-hart-and-the-hunt...           243
#
#                                            categories  rating  \
# 0   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 2   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 3             [{'alias': 'bbq', 'title': 'Barbeque'}]     4.5
# 4   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 5   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 6             [{'alias': 'bbq', 'title': 'Barbeque'}]     4.0
# 7   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 8   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 9   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 10  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 11  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 12  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     5.0
# 13  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.0
# 14  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 15  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 16  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 17  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 18  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.0
# 19  [{'alias': 'southern', 'title': 'Southern'}, {...     4.0
#
#                                           coordinates  \
# 0     {'latitude': 47.59906, 'longitude': -122.29914}
# 1   {'latitude': 47.59734508353989, 'longitude': -...
# 2     {'latitude': 47.60248, 'longitude': -122.33167}
# 3   {'latitude': 47.608664, 'longitude': -122.340955}
# 4     {'latitude': 47.59847, 'longitude': -122.32471}
# 5   {'latitude': 47.568253286253, 'longitude': -12...
# 6      {'latitude': 47.58215, 'longitude': -122.3338}
# 7    {'latitude': 47.594464, 'longitude': -122.31013}
# 8     {'latitude': 47.59763, 'longitude': -122.32415}
# 9   {'latitude': 47.614331, 'longitude': -122.325201}
# 10    {'latitude': 47.60453, 'longitude': -122.33061}
# 11    {'latitude': 47.59779, 'longitude': -122.32601}
# 12  {'latitude': 47.6112518310547, 'longitude': -1...
# 13  {'latitude': 47.59805457325023, 'longitude': -...
# 14  {'latitude': 47.620538, 'longitude': -122.339396}
# 15    {'latitude': 47.59821, 'longitude': -122.32339}
# 16  {'latitude': 47.624618, 'longitude': -122.321194}
# 17  {'latitude': 47.608949, 'longitude': -122.340599}
# 18    {'latitude': 47.59901, 'longitude': -122.32469}
# 19    {'latitude': 47.60989, 'longitude': -122.34038}
#
#                           transactions price  \
# 0                   [delivery, pickup]    $$
# 1                                   []   NaN
# 2                   [delivery, pickup]     $
# 3                   [delivery, pickup]    $$
# 4                           [delivery]    $$
# 5                   [delivery, pickup]    $$
# 6                   [delivery, pickup]    $$
# 7                                   []   NaN
# 8                           [delivery]     $
# 9                   [delivery, pickup]  $$$$
# 10                  [delivery, pickup]   NaN
# 11                          [delivery]     $
# 12                                  []   NaN
# 13                          [delivery]   $$$
# 14                  [delivery, pickup]    $$
# 15                  [delivery, pickup]    $$
# 16  [delivery, restaurant_reservation]   NaN
# 17                          [delivery]    $$
# 18                            [pickup]    $$
# 19                  [delivery, pickup]    $$
#
#                                              location         phone  \
# 0   {'address1': '2513 S Jackson St', 'address2': ...  +12064857381
# 1   {'address1': '609 S Weller St', 'address2': 'S...  +12062238528
# 2   {'address1': '215 James St', 'address2': '', '...  +12066228717
# 3   {'address1': '1505 Pike Pl', 'address2': None,...  +12065380779
# 4   {'address1': '656 S King St', 'address2': None...  +12066824006
# 5   {'address1': '3924 Airport Way S', 'address2':...  +12064674038
# 6   {'address1': '2260 1st Ave S', 'address2': '',...  +12066230629
# 7   {'address1': '898 Rainier Ave S', 'address2': ...  +12062355111
# 8   {'address1': '668 S Weller St', 'address2': ''...  +12066223388
# 9   {'address1': '500 E Pike St', 'address2': None...  +12066952621
# 10  {'address1': '701 5th Ave', 'address2': '', 'a...  +12064674038
# 11  {'address1': '518 6th Ave S', 'address2': '', ...  +12066222828
# 12  {'address1': '', 'address2': '', 'address3': N...  +12069600460
# 13  {'address1': '509 7th Ave S', 'address2': '', ...  +12064857137
# 14  {'address1': '228 9th Ave N', 'address2': None...  +12067087642
# 15  {'address1': '707 S King St', 'address2': '', ...  +12066212228
# 16  {'address1': '611 Broadway E', 'address2': Non...  +14254550898
# 17  {'address1': '94 Pike St', 'address2': 'Ste 30...  +12064674268
# 18  {'address1': '655 S Jackson St', 'address2': '...  +12066242275
# 19  {'address1': '111 Pine St', 'address2': '', 'a...  +12065960700
#
#      display_phone     distance
# 0   (206) 485-7381  2310.983284
# 1   (206) 223-8528   607.529068
# 2   (206) 622-8717   158.063815
# 3   (206) 538-0779  1108.136215
# 4   (206) 682-4006   564.151186
# 5   (206) 467-4038  3816.251573
# 6   (206) 623-0629  2254.663043
# 7   (206) 235-5111  1700.985913
# 8   (206) 622-3388   652.859957
# 9   (206) 695-2621  1387.177191
# 10  (206) 467-4038   265.750476
# 11  (206) 622-2828   560.177196
# 12  (206) 960-0460   860.500070
# 13  (206) 485-7137   620.532899
# 14  (206) 708-7642  2162.810885
# 15  (206) 621-2228   648.008687
# 16  (425) 455-0898  2569.097538
# 17  (206) 467-4268  1109.014255
# 18  (206) 624-2275   523.233793
# 19  (206) 596-0700  1163.763480

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/ results_per_page
# Out:
# 26.55

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 27

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    ## use n_results as the OFFSET 
    results = yelp.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    # add a 200ms pause
    time.sleep(.2)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %% [markdown]
# ## Convert json to dataframe

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                             alias  \
# 0  E0jzAxh2u7ifsOeZ4qnp6A             wood-shop-bbq-seattle
# 1  oom3dxWO6NVPmbXYanCfqQ  bellwether-bbq-and-grill-seattle
# 2  fy8zyFKcG45cfh3PvYvx-Q      hole-in-the-wall-bbq-seattle
# 3  HZTlGFXupOqtPCyYkdeDIw       pikes-pit-bar-b-que-seattle
# 4  e8UiD4SOyfyv5PIB5i1EvQ          kau-kau-barbeque-seattle
#
#                    name                                          image_url  \
# 0         Wood Shop BBQ  https://s3-media3.fl.yelpcdn.com/bphoto/ta1019...
# 1  Bellwether BBQ&Grill  https://s3-media1.fl.yelpcdn.com/bphoto/pBwgaV...
# 2  Hole In the Wall BBQ  https://s3-media1.fl.yelpcdn.com/bphoto/8UipIn...
# 3  Pike's Pit Bar-B-Que  https://s3-media1.fl.yelpcdn.com/bphoto/wHUjh9...
# 4      Kau Kau Barbeque  https://s3-media3.fl.yelpcdn.com/bphoto/rq0CJN...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/wood-shop-bbq-seattle...           688
# 1      False  https://www.yelp.com/biz/bellwether-bbq-and-gr...            26
# 2      False  https://www.yelp.com/biz/hole-in-the-wall-bbq-...           271
# 3      False  https://www.yelp.com/biz/pikes-pit-bar-b-que-s...           251
# 4      False  https://www.yelp.com/biz/kau-kau-barbeque-seat...          1202
#
#                                           categories  rating  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 3            [{'alias': 'bbq', 'title': 'Barbeque'}]     4.5
# 4  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 47.59906, 'longitude': -122.29914}  [pickup, delivery]
# 1  {'latitude': 47.59734508353989, 'longitude': -...                  []
# 2    {'latitude': 47.60248, 'longitude': -122.33167}  [pickup, delivery]
# 3  {'latitude': 47.608664, 'longitude': -122.340955}  [pickup, delivery]
# 4    {'latitude': 47.59847, 'longitude': -122.32471}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '2513 S Jackson St', 'address2': ...  +12064857381
# 1   NaN  {'address1': '609 S Weller St', 'address2': 'S...  +12062238528
# 2     $  {'address1': '215 James St', 'address2': '', '...  +12066228717
# 3    $$  {'address1': '1505 Pike Pl', 'address2': None,...  +12065380779
# 4    $$  {'address1': '656 S King St', 'address2': None...  +12066824006
#
#     display_phone     distance
# 0  (206) 485-7381  2310.983284
# 1  (206) 223-8528   607.529068
# 2  (206) 622-8717   158.063815
# 3  (206) 538-0779  1108.136215
# 4  (206) 682-4006   564.151186

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             531 non-null    object
#  1   alias          531 non-null    object
#  2   name           531 non-null    object
#  3   image_url      531 non-null    object
#  4   is_closed      531 non-null    bool
#  5   url            531 non-null    object
#  6   review_count   531 non-null    int64
#  7   categories     531 non-null    object
#  8   rating         531 non-null    float64
#  9   coordinates    531 non-null    object
#  10  transactions   531 non-null    object
#  11  price          459 non-null    object
#  12  location       531 non-null    object
#  13  phone          531 non-null    object
#  14  display_phone  531 non-null    object
#  15  distance       531 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 62.9+ KB

# %%
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Seattle-bbq.csv.gz'

# %%
df.to_csv(csv_file, compression = 'gzip', index=False)

# %% [markdown]
# ## compare file size

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json', '.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CVS.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz:,} times smaller!!!')
# Out:
# JSON FILE: 520,759 Bytes
# CVS.GZ FILE: 74,257 Bytes
# the csv.gz is 7.012928074120958 times smaller!!!
